# %% [markdown]
# <a href="https://colab.research.google.com/github/rifqiilhamifauzi/SM-Praktikum2/blob/main/SM_Praktikum2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt
# Membaca gambar
image = cv2.imread('sample.jpeg')

# Resize gambar
resized = cv2.resize(image, (300, 300))

# Crop gambar
cropped = image[50:250, 50:250]

# Flip gambar
flipped = cv2.flip(image, 1)

# Rotate gambar
(h, w) = image.shape[:2]

center = (w / 2, h / 2)
M = cv2.getRotationMatrix2D(center, 270, 0.5) # Rotasi 90 derajat
rotated = cv2.warpAffine(image, M, (w, h))

# Menampilkan hasil
plt.figure(figsize=(10, 5))
plt.subplot(1, 4, 1)
plt.imshow(cv2.cvtColor(resized, cv2.COLOR_BGR2RGB))
plt.title('Resized')

plt.subplot(1, 4, 2)
plt.imshow(cv2.cvtColor(cropped, cv2.COLOR_BGR2RGB))
plt.title('Cropped')

plt.subplot(1, 4, 3)
plt.imshow(cv2.cvtColor(flipped, cv2.COLOR_BGR2RGB))
plt.title('Flipped')

plt.subplot(1, 4, 4) # Menambahkan subplot untuk gambar yang dirotasi
plt.imshow(cv2.cvtColor(rotated, cv2.COLOR_BGR2RGB))
plt.title('Rotated')

plt.show()
